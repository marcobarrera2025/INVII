# %% [markdown]
# # <span style="color:blue"><b>PROYECTO FINAL</b></span>
#
# # <span style="color:blue"><b>SISTEMA DE AUTENTICACIÓN MULTIPARTE DE CARTERAS</b></span>
#
#
# #Integrantes
# ### ● Jesus Campos
# ### ● Marco Barrera

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
# !ls /content/drive/MyDrive/PI_II
# Out:
#  Autenticacion_Carteras__Metricas_v03.ipynb
#  Chanel_Parts.zip
#  chanel.zip
#  Ch_parts_v2
#  DATASET
#  DATASET.zip
# 'Guía Experta: Autenticación de Carteras Chanel.gdoc'
#  modelo_autenticacion.h5
#  modelo_autenticacion.keras
#  modelo_logo_turnlock_balanceado.keras
#  modelo_logo_turnlock_corregido.keras
#  modelo_logo_turnlock.keras
#  pipeline_autenticacion.docx
#  pipeline_autenticacion_v2.docx
#  Proyecto_Pipeline_COMPLETO.docx
#  Proyecto_Pipeline.docx
#  Proyecto_Pipeline_final.docx
#  VERSION_01
#  VERSION_02
#  yolo_chanel.ipynb

# %%
import shutil
import os

SRC_ZIP = "/content/drive/MyDrive/PI_II/chanel.zip"
DST_ZIP = "/content/chanel.zip"

print("Copiando ZIP a disco local...")
shutil.copy2(SRC_ZIP, DST_ZIP)
print("ZIP copiado a /content/")
# Out:
# Copiando ZIP a disco local...
# ZIP copiado a /content/

# %%
import zipfile

with zipfile.ZipFile("/content/chanel.zip", "r") as z:
    for name in z.namelist()[:30]:
        print(name)
# Out:
# chanel/
# chanel/fake/
# chanel/fake/bag---2.55/
# chanel/fake/bag---2.55/0104/
# chanel/fake/bag---2.55/0104/0104_1.jpg
# chanel/fake/bag---2.55/0104/0104_2.jpg
# chanel/fake/bag---2.55/0104/0104_3.jpg
# chanel/fake/bag---2.55/0104/0104_4.jpg
# chanel/fake/bag---2.55/0105/
# chanel/fake/bag---2.55/0105/0105_1.jpg
# chanel/fake/bag---2.55/0105/0105_2.jpg
# chanel/fake/bag---2.55/0105/0105_3.jpg
# chanel/fake/bag---2.55/0105/0105_4.jpg
# chanel/fake/bag---2.55/0105/0105_5.jpg
# chanel/fake/bag---2.55/0106/
# chanel/fake/bag---2.55/0106/0106_1.jpg
# chanel/fake/bag---2.55/0106/0106_2.jpg
# chanel/fake/bag---2.55/0107/
# chanel/fake/bag---2.55/0107/0107_1.jpg
# chanel/fake/bag---2.55/0107/0107_2.jpg
# chanel/fake/bag---2.55/0107/0107_3.jpg
# chanel/fake/bag---2.55/0107/0107_4.jpg
# chanel/fake/bag---2.55/0107/0107_5.jpg
# chanel/fake/bag---2.55/0107/0107_6.jpg
# chanel/fake/bag---2.55/0107/0107_7.jpg
# chanel/fake/bag---2.55/0107/0107_8.jpg
# chanel/fake/bag---2.55/0107/0107_9.jpg
# chanel/fake/bag---2.55/0108/
# chanel/fake/bag---2.55/0108/0108_1.jpg
# chanel/fake/bag---2.55/0108/0108_2.jpg

# %%
import zipfile

EXTRACT_DIR = "/content/data"
os.makedirs(EXTRACT_DIR, exist_ok=True)

print("Descomprimiendo ZIP en /content/data...")
with zipfile.ZipFile(DST_ZIP, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print("Dataset descomprimido en /content/data")
# Out:
# Descomprimiendo ZIP en /content/data...
# Dataset descomprimido en /content/data

# %%
# !ls /content/data/chanel
# Out:
# fake  genuine

# %% [markdown]
# ### <span style="color:#7b1e3a"><b>Split 70/15/15</b></span>
#
# Se divide el dataset en 70% para entrenamiento del modelo, 15% para validación durante el ajuste y 15% para prueba final, garantizando una evaluación objetiva del rendimiento.

# %%
import os
import numpy as np
from sklearn.model_selection import GroupShuffleSplit

BASE_DIR = "/content/data/chanel"

data = []

for label_name in ["genuine", "fake"]:
    label = 1 if label_name == "genuine" else 0
    label_path = os.path.join(BASE_DIR, label_name)

    for bag_type in os.listdir(label_path):
        bag_path = os.path.join(label_path, bag_type)

        for group in os.listdir(bag_path):
            group_path = os.path.join(bag_path, group)

            for img in os.listdir(group_path):
                img_path = os.path.join(group_path, img)
                data.append((img_path, label, group))

data = np.array(data)

X = data[:, 0]
y = data[:, 1].astype(int)
groups = data[:, 2]

gss = GroupShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
train_idx, temp_idx = next(gss.split(X, y, groups))

X_train, y_train = X[train_idx], y[train_idx]
groups_train = groups[train_idx]

X_temp, y_temp = X[temp_idx], y[temp_idx]
groups_temp = groups[temp_idx]

gss2 = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(gss2.split(X_temp, y_temp, groups_temp))

X_val, y_val = X_temp[val_idx], y_temp[val_idx]
X_test, y_test = X_temp[test_idx], y_temp[test_idx]

print(len(X_train), len(X_val), len(X_test))
# Out:
# 10720 2451 2270

# %%
from PIL import Image
import numpy as np

def is_valid_image(path):
    try:
        with Image.open(path) as img:
            img.verify()
        return True
    except:
        return False

def clean_dataset(X, y):
    valid_X = []
    valid_y = []
    invalid = []

    for path, label in zip(X, y):
        if is_valid_image(path):
            valid_X.append(path)
            valid_y.append(label)
        else:
            invalid.append(path)

    return np.array(valid_X), np.array(valid_y), invalid

X_train, y_train, invalid_train = clean_dataset(X_train, y_train)
X_val, y_val, invalid_val = clean_dataset(X_val, y_val)
X_test, y_test, invalid_test = clean_dataset(X_test, y_test)

print("Invalid train:", len(invalid_train))
print("Invalid val:", len(invalid_val))
print("Invalid test:", len(invalid_test))

print(invalid_train[:10])
print(invalid_val[:10])
print(invalid_test[:10])
# Out:
# Invalid train: 0
# Invalid val: 0
# Invalid test: 0
# []
# []
# []

# %% [markdown]
# ### <span style="color:#7b1e3a"><b>Cargar y preparar las imágenes</b></span>
# (data pipeline)

# %%
import tensorflow as tf

IMG_SIZE = 224
BATCH_SIZE = 32

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.cast(img, tf.float32)
    img = tf.keras.applications.efficientnet.preprocess_input(img)
    return img, label

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_ds = val_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_ds = test_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### <span style="color:#800020"><b>Entrenamiento del Modelo para Autenticación de Carteras</b></span>
#
# Se entrena un modelo de clasificación binaria para distinguir entre carteras genuinas y falsas usando EfficientNetB0.
# Se utiliza validación y early stopping para mejorar la generalización y evitar sobreajuste.

# %%
import tensorflow as tf

base_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)

base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(2, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[early_stop]
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 108s 211ms/step - accuracy: 0.8164 - loss: 0.4488 - val_accuracy: 0.3488 - val_loss: 1.1458
# Epoch 2/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.7782 - loss: 0.4875 - val_accuracy: 0.4598 - val_loss: 0.9208
# Epoch 3/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8069 - loss: 0.4244 - val_accuracy: 0.5537 - val_loss: 0.7983
# Epoch 4/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.8295 - loss: 0.3834 - val_accuracy: 0.6047 - val_loss: 0.7353
# Epoch 5/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8455 - loss: 0.3547 - val_accuracy: 0.6557 - val_loss: 0.6806
# Epoch 6/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8543 - loss: 0.3347 - val_accuracy: 0.6809 - val_loss: 0.6501
# Epoch 7/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8599 - loss: 0.3191 - val_accuracy: 0.6932 - val_loss: 0.6263
# Epoch 8/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8682 - loss: 0.3046 - val_accuracy: 0.7152 - val_loss: 0.5940
# Epoch 9/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8766 - loss: 0.2903 - val_accuracy: 0.7430 - val_loss: 0.5632
# Epoch 10/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8825 - loss: 0.2791 - val_accuracy: 0.7503 - val_loss: 0.5506
# Epoch 11/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8860 - loss: 0.2711 - val_accuracy: 0.7572 - val_loss: 0.5462
# Epoch 12/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8874 - loss: 0.2643 - val_accuracy: 0.7576 - val_loss: 0.5446
# Epoch 13/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8948 - loss: 0.2589 - val_accuracy: 0.7707 - val_loss: 0.5181
# Epoch 14/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8948 - loss: 0.2529 - val_accuracy: 0.7736 - val_loss: 0.5095
# Epoch 15/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8977 - loss: 0.2444 - val_accuracy: 0.7736 - val_loss: 0.5070
# Epoch 16/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.8987 - loss: 0.2417 - val_accuracy: 0.7809 - val_loss: 0.4918
# Epoch 17/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9030 - loss: 0.2329 - val_accuracy: 0.7805 - val_loss: 0.4925
# Epoch 18/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9029 - loss: 0.2310 - val_accuracy: 0.7887 - val_loss: 0.4760
# Epoch 19/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9023 - loss: 0.2314 - val_accuracy: 0.7878 - val_loss: 0.4786
# Epoch 20/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.9061 - loss: 0.2246 - val_accuracy: 0.7936 - val_loss: 0.4730
# Epoch 21/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.9049 - loss: 0.2274 - val_accuracy: 0.7980 - val_loss: 0.4649
# Epoch 22/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.9100 - loss: 0.2187 - val_accuracy: 0.8001 - val_loss: 0.4608
# Epoch 23/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9111 - loss: 0.2169 - val_accuracy: 0.8029 - val_loss: 0.4556
# Epoch 24/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9133 - loss: 0.2166 - val_accuracy: 0.8058 - val_loss: 0.4530
# Epoch 25/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9102 - loss: 0.2135 - val_accuracy: 0.8144 - val_loss: 0.4404
# Epoch 26/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9122 - loss: 0.2096 - val_accuracy: 0.8103 - val_loss: 0.4485
# Epoch 27/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9133 - loss: 0.2112 - val_accuracy: 0.8111 - val_loss: 0.4469
# Epoch 28/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9151 - loss: 0.2076 - val_accuracy: 0.8164 - val_loss: 0.4390
# Epoch 29/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9187 - loss: 0.2079 - val_accuracy: 0.8188 - val_loss: 0.4321
# Epoch 30/30
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9166 - loss: 0.2039 - val_accuracy: 0.8168 - val_loss: 0.4401

# %% [markdown]
# ### <span style="color:#800020"><b>Evaluación del Modelo en el Conjunto de Prueba</b></span>

# %%
test_loss, test_acc = model.evaluate(test_ds)

print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 22s 312ms/step - accuracy: 0.8469 - loss: 0.3518
# Test loss: 0.35175031423568726
# Test accuracy: 0.8469342589378357

# %% [markdown]
# ### <span style="color:#800020"><b>Guardar modelo en Google Drive</b></span>

# %%
from google.colab import drive
drive.mount('/content/drive')

model.save("/content/drive/MyDrive/PI_II/modelo_autenticacion.keras")
model.save("/content/drive/MyDrive/PI_II/modelo_autenticacion.h5")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### <span style="color:#800020"><b>Gráficas de Entrenamiento del Modelo</b></span>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig("/content/drive/MyDrive/graficas_entrenamiento.png")
plt.show()

# %% [markdown]
# ### <span style="color:#800020"><b>Matriz de Confusión del Modelo</b></span>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    classes = np.argmax(preds, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(classes)

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Fake","Genuine"])
disp.plot()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %% [markdown]
# ### <span style="color:#800020"><b>Reporte de Clasificación</b></span>

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred, target_names=["Fake","Genuine"]))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.98      0.81       750
#      Genuine       0.99      0.78      0.87      1517
#
#     accuracy                           0.85      2267
#    macro avg       0.84      0.88      0.84      2267
# weighted avg       0.89      0.85      0.85      2267

# %%
import zipfile, os, shutil

ZIP_PATH = "/content/drive/MyDrive/PI_II/Chanel_Parts.zip"
DEST_DIR = "/content/Chanel_Parts"

if os.path.exists(DEST_DIR):
    shutil.rmtree(DEST_DIR)

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall("/content")

print("Dataset descomprimido")
print(os.listdir(DEST_DIR))
# Out:
# Dataset descomprimido
# ['genuine', 'fake']

# %%
import zipfile
import os
import shutil
import pandas as pd

ZIP_PATH = "/content/drive/MyDrive/PI_II/Chanel_Parts.zip"
DEST_DIR = "/content/Chanel_Parts"

if os.path.exists(DEST_DIR):
    shutil.rmtree(DEST_DIR)

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall("/content")

print("Dataset descomprimido")

# extensiones válidas de imágenes
IMG_EXT = ('.jpg', '.jpeg', '.png', '.bmp', '.webp')

data = []

for root, dirs, files in os.walk(DEST_DIR):
    img_count = sum(1 for f in files if f.lower().endswith(IMG_EXT))

    if img_count > 0:
        rel_path = os.path.relpath(root, DEST_DIR)
        data.append([rel_path, img_count])

df = pd.DataFrame(data, columns=["Carpeta", "Cantidad_Imagenes"])

# ordenar por cantidad
df = df.sort_values(by="Cantidad_Imagenes", ascending=False)

# mostrar tabla
print(df.to_string(index=False))

# total general
print("\nTOTAL DE IMÁGENES:", df["Cantidad_Imagenes"].sum())
# Out:
# Dataset descomprimido
#            Carpeta  Cantidad_Imagenes
#  genuine/bag---boy               1632
# genuine/bag---2.55                414
#     fake/bag---boy                 51
#    fake/bag---2.55                 32
#
# TOTAL DE IMÁGENES: 2129

# %% [markdown]
# ### <span style="color:#800020"><b>Modelo de Partes</b></span>
#
# modelo adicional de autenticación basado en componentes específicos de carteras Chanel. El modelo fue entrenado utilizando imágenes de las partes logo y turnlock de los modelos Chanel 2.55 y Boy, clasificándolas en las categorías genuine y fake. Para el entrenamiento se utilizó la arquitectura EfficientNetB0 mediante transferencia de aprendizaje, logrando una precisión de validación aproximada de 71.43%.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

DATA_DIR = "/content/Chanel_Parts"
IMG_SIZE = (224,224)
BATCH_SIZE = 16

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR, validation_split=0.2, subset="validation",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
print(class_names)

y_train = []
for _, labels in train_ds:
    y_train.extend(labels.numpy())

class_weights = dict(enumerate(compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)))

print(class_weights)

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    layers.RandomFlip("horizontal"),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    class_weight=class_weights
)

model.save("/content/drive/MyDrive/PI_II/modelo_logo_turnlock_corregido.keras")
# Out:
# Found 2129 files belonging to 2 classes.
# Using 1704 files for training.
# Found 2129 files belonging to 2 classes.
# Using 425 files for validation.
# ['fake', 'genuine']
# {0: np.float64(12.716417910447761), 1: np.float64(0.5204642638973732)}
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 78s 412ms/step - accuracy: 0.8175 - loss: 0.6579 - val_accuracy: 0.8894 - val_loss: 0.5228
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8421 - loss: 0.5828 - val_accuracy: 0.8941 - val_loss: 0.5000
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8650 - loss: 0.5197 - val_accuracy: 0.8824 - val_loss: 0.4844
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8703 - loss: 0.4989 - val_accuracy: 0.8824 - val_loss: 0.4704
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8750 - loss: 0.4465 - val_accuracy: 0.8988 - val_loss: 0.4393
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8815 - loss: 0.4040 - val_accuracy: 0.9059 - val_loss: 0.4105
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8961 - loss: 0.3980 - val_accuracy: 0.9012 - val_loss: 0.4045
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9032 - loss: 0.3828 - val_accuracy: 0.8965 - val_loss: 0.3909
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9055 - loss: 0.3464 - val_accuracy: 0.9129 - val_loss: 0.3656
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9137 - loss: 0.3442 - val_accuracy: 0.9153 - val_loss: 0.3522

# %% [markdown]
# **Precisión de Entrenamiento y Validación**

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.show()

# %%
loss, accuracy = model.evaluate(val_ds)

print(f"Validation Accuracy: {accuracy*100:.2f}%")
print(f"Validation Loss: {loss:.4f}")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9153 - loss: 0.3522
# Validation Accuracy: 91.53%
# Validation Loss: 0.3522

# %% [markdown]
# **Matriz de Confusión del Modelo de Autenticación de Partes**

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int)

    y_true.extend(labels.numpy())
    y_pred.extend(preds.flatten())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Real")
plt.title("Confusion Matrix")
plt.show()

print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
#               precision    recall  f1-score   support
#
#            0       0.30      0.94      0.45        16
#            1       1.00      0.91      0.95       409
#
#     accuracy                           0.92       425
#    macro avg       0.65      0.93      0.70       425
# weighted avg       0.97      0.92      0.94       425

# %% [markdown]
#  **Evaluación de Umbral Global para Autenticación por Múltiples Partes**

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, balanced_accuracy_score

DATA_DIR = "/content/Chanel_Parts"
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS = 10
N_SPLITS = 5
SEED = 123
PARTES_POR_CARTERA = 2

tmp_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = tmp_ds.class_names
file_paths = np.array(tmp_ds.file_paths)
labels = np.array([int(y.numpy()) for _, y in tmp_ds.unbatch()])

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = tf.keras.applications.efficientnet.preprocess_input(img)
    return img, label

def build_dataset(paths, labels, training=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if training:
        ds = ds.shuffle(1000, seed=SEED)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

def build_model():
    base_model = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(224, 224, 3)
    )

    base_model.trainable = False

    model = models.Sequential([
        layers.Input(shape=(224, 224, 3)),
        layers.RandomFlip("horizontal"),
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.3),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

kfold = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)

thresholds = np.arange(0.70, 0.91, 0.05)

fold_results = []
threshold_results_all = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(file_paths, labels), start=1):

    train_paths = file_paths[train_idx]
    train_labels = labels[train_idx]
    val_paths = file_paths[val_idx]
    val_labels = labels[val_idx]

    train_ds = build_dataset(train_paths, train_labels, training=True)
    val_ds = build_dataset(val_paths, val_labels, training=False)

    class_weights = dict(enumerate(compute_class_weight(
        class_weight="balanced",
        classes=np.unique(train_labels),
        y=train_labels
    )))

    model_cv = build_model()

    model_cv.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        class_weight=class_weights,
        verbose=1
    )

    probs_part = model_cv.predict(val_ds, verbose=0).flatten()

    n = len(probs_part) // PARTES_POR_CARTERA

    probs_part = probs_part[:n * PARTES_POR_CARTERA]
    val_labels_cut = val_labels[:n * PARTES_POR_CARTERA]

    prob_matrix = probs_part.reshape(n, PARTES_POR_CARTERA)
    label_matrix = val_labels_cut.reshape(n, PARTES_POR_CARTERA)

    score_global = prob_matrix.min(axis=1)
    y_true_global = label_matrix.max(axis=1)

    best_row = None

    for threshold in thresholds:

        y_pred_global = (score_global >= threshold).astype(int)

        cm = confusion_matrix(y_true_global, y_pred_global, labels=[0, 1])

        row = {
            "fold": fold,
            "threshold": round(float(threshold), 2),
            "accuracy": accuracy_score(y_true_global, y_pred_global),
            "balanced_accuracy": balanced_accuracy_score(y_true_global, y_pred_global),
            "precision_genuine": precision_score(y_true_global, y_pred_global, pos_label=1, zero_division=0),
            "recall_genuine": recall_score(y_true_global, y_pred_global, pos_label=1, zero_division=0),
            "f1_genuine": f1_score(y_true_global, y_pred_global, pos_label=1, zero_division=0),
            "fake_as_genuine": cm[0, 1],
            "genuine_as_fake": cm[1, 0],
            "confusion_matrix": cm.tolist()
        }

        threshold_results_all.append(row)

        if best_row is None:
            best_row = row
        elif (
            row["fake_as_genuine"] < best_row["fake_as_genuine"] or
            (
                row["fake_as_genuine"] == best_row["fake_as_genuine"] and
                row["balanced_accuracy"] > best_row["balanced_accuracy"]
            ) or
            (
                row["fake_as_genuine"] == best_row["fake_as_genuine"] and
                row["balanced_accuracy"] == best_row["balanced_accuracy"] and
                row["threshold"] > best_row["threshold"]
            )
        ):
            best_row = row

    fold_results.append(best_row)

df_thresholds_cv = pd.DataFrame(threshold_results_all)
df_best_folds = pd.DataFrame(fold_results)

display(df_thresholds_cv)
display(df_best_folds)

UMBRAL_GLOBAL_FINAL = df_best_folds["threshold"].median()

print("UMBRAL GLOBAL FINAL:", UMBRAL_GLOBAL_FINAL)
print("PROMEDIO:", df_best_folds["threshold"].mean())
print("MEDIANA:", df_best_folds["threshold"].median())
print("STD:", df_best_folds["threshold"].std())
# Out:
# Found 2129 files belonging to 2 classes.
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 203ms/step - accuracy: 0.7563 - loss: 0.7376 - val_accuracy: 0.8451 - val_loss: 0.5542
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7616 - loss: 0.6472 - val_accuracy: 0.8850 - val_loss: 0.5193
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8015 - loss: 0.5949 - val_accuracy: 0.8873 - val_loss: 0.4821
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8491 - loss: 0.5481 - val_accuracy: 0.8967 - val_loss: 0.4617
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8708 - loss: 0.5014 - val_accuracy: 0.8944 - val_loss: 0.4398
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8843 - loss: 0.4662 - val_accuracy: 0.9108 - val_loss: 0.4134
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8914 - loss: 0.4341 - val_accuracy: 0.9038 - val_loss: 0.3945
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8984 - loss: 0.4031 - val_accuracy: 0.9131 - val_loss: 0.3683
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9137 - loss: 0.3844 - val_accuracy: 0.9131 - val_loss: 0.3541
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9131 - loss: 0.3538 - val_accuracy: 0.9131 - val_loss: 0.3356
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 43s 205ms/step - accuracy: 0.6806 - loss: 0.7224 - val_accuracy: 0.7629 - val_loss: 0.6018
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6923 - loss: 0.6187 - val_accuracy: 0.7793 - val_loss: 0.5514
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7692 - loss: 0.5745 - val_accuracy: 0.8146 - val_loss: 0.5069
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7968 - loss: 0.5282 - val_accuracy: 0.8333 - val_loss: 0.4741
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8180 - loss: 0.4832 - val_accuracy: 0.8709 - val_loss: 0.4430
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8467 - loss: 0.4569 - val_accuracy: 0.8803 - val_loss: 0.4194
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8638 - loss: 0.4149 - val_accuracy: 0.8873 - val_loss: 0.3962
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8802 - loss: 0.3921 - val_accuracy: 0.9038 - val_loss: 0.3700
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8884 - loss: 0.3828 - val_accuracy: 0.9131 - val_loss: 0.3552
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8996 - loss: 0.3327 - val_accuracy: 0.9319 - val_loss: 0.3286
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 198ms/step - accuracy: 0.7410 - loss: 0.6545 - val_accuracy: 0.8474 - val_loss: 0.5260
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8027 - loss: 0.5934 - val_accuracy: 0.9085 - val_loss: 0.4831
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8344 - loss: 0.5445 - val_accuracy: 0.9272 - val_loss: 0.4496
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8726 - loss: 0.4959 - val_accuracy: 0.9249 - val_loss: 0.4254
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8814 - loss: 0.4471 - val_accuracy: 0.9155 - val_loss: 0.4040
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8967 - loss: 0.4276 - val_accuracy: 0.9202 - val_loss: 0.3870
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8767 - loss: 0.4063 - val_accuracy: 0.9131 - val_loss: 0.3722
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8943 - loss: 0.3990 - val_accuracy: 0.9155 - val_loss: 0.3612
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9049 - loss: 0.3513 - val_accuracy: 0.9178 - val_loss: 0.3439
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9043 - loss: 0.3401 - val_accuracy: 0.9178 - val_loss: 0.3293
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 43s 203ms/step - accuracy: 0.4903 - loss: 0.6901 - val_accuracy: 0.6150 - val_loss: 0.6310
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6301 - loss: 0.6353 - val_accuracy: 0.7653 - val_loss: 0.5560
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7452 - loss: 0.5658 - val_accuracy: 0.8380 - val_loss: 0.4927
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8144 - loss: 0.5177 - val_accuracy: 0.8709 - val_loss: 0.4573
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8250 - loss: 0.4943 - val_accuracy: 0.8873 - val_loss: 0.4299
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8661 - loss: 0.4371 - val_accuracy: 0.9014 - val_loss: 0.3986
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8767 - loss: 0.4096 - val_accuracy: 0.9108 - val_loss: 0.3803
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8961 - loss: 0.3838 - val_accuracy: 0.9225 - val_loss: 0.3553
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9096 - loss: 0.3517 - val_accuracy: 0.9225 - val_loss: 0.3383
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9084 - loss: 0.3476 - val_accuracy: 0.9225 - val_loss: 0.3260
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 203ms/step - accuracy: 0.7394 - loss: 0.7867 - val_accuracy: 0.7788 - val_loss: 0.5720
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7001 - loss: 0.7041 - val_accuracy: 0.7553 - val_loss: 0.5611
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7347 - loss: 0.6507 - val_accuracy: 0.7812 - val_loss: 0.5317
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7565 - loss: 0.5884 - val_accuracy: 0.8024 - val_loss: 0.4985
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7899 - loss: 0.5338 - val_accuracy: 0.8188 - val_loss: 0.4756
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8286 - loss: 0.5028 - val_accuracy: 0.8753 - val_loss: 0.4332
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8451 - loss: 0.4859 - val_accuracy: 0.8965 - val_loss: 0.4138
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8656 - loss: 0.4276 - val_accuracy: 0.9294 - val_loss: 0.3884
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8732 - loss: 0.4166 - val_accuracy: 0.9388 - val_loss: 0.3693
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8885 - loss: 0.3739 - val_accuracy: 0.9506 - val_loss: 0.3306
#     fold  threshold  accuracy  balanced_accuracy  precision_genuine  \
# 0      1       0.70  0.563380           0.773171                1.0
# 1      1       0.75  0.441315           0.709756                1.0
# 2      1       0.80  0.276995           0.624390                1.0
# 3      1       0.85  0.112676           0.539024                1.0
# 4      1       0.90  0.046948           0.504878                1.0
# 5      2       0.70  0.511737           0.746341                1.0
# 6      2       0.75  0.436620           0.707317                1.0
# 7      2       0.80  0.384977           0.680488                1.0
# 8      2       0.85  0.276995           0.624390                1.0
# 9      2       0.90  0.112676           0.539024                1.0
# 10     3       0.70  0.572770           0.778049                1.0
# 11     3       0.75  0.474178           0.726829                1.0
# 12     3       0.80  0.352113           0.663415                1.0
# 13     3       0.85  0.201878           0.585366                1.0
# 14     3       0.90  0.065728           0.514634                1.0
# 15     4       0.70  0.563380           0.773171                1.0
# 16     4       0.75  0.446009           0.712195                1.0
# 17     4       0.80  0.342723           0.658537                1.0
# 18     4       0.85  0.211268           0.590244                1.0
# 19     4       0.90  0.084507           0.524390                1.0
# 20     5       0.70  0.542453           0.762255                1.0
# 21     5       0.75  0.443396           0.710784                1.0
# 22     5       0.80  0.358491           0.666667                1.0
# 23     5       0.85  0.146226           0.556373                1.0
# 24     5       0.90  0.051887           0.507353                1.0
#
#     recall_genuine  f1_genuine  fake_as_genuine  genuine_as_fake  \
# 0         0.546341    0.706625                0               93
# 1         0.419512    0.591065                0              119
# 2         0.248780    0.398438                0              154
# 3         0.078049    0.144796                0              189
# 4         0.009756    0.019324                0              203
# 5         0.492683    0.660131                0              104
# 6         0.414634    0.586207                0              120
# 7         0.360976    0.530466                0              131
# 8         0.248780    0.398438                0              154
# 9         0.078049    0.144796                0              189
# 10        0.556098    0.714734                0               91
# 11        0.453659    0.624161                0              112
# 12        0.326829    0.492647                0              138
# 13        0.170732    0.291667                0              170
# 14        0.029268    0.056872                0              199
# 15        0.546341    0.706625                0               93
# 16        0.424390    0.595890                0              118
# 17        0.317073    0.481481                0              140
# 18        0.180488    0.305785                0              168
# 19        0.048780    0.093023                0              195
# 20        0.524510    0.688103                0               97
# 21        0.421569    0.593103                0              118
# 22        0.333333    0.500000                0              136
# 23        0.112745    0.202643                0              181
# 24        0.014706    0.028986                0              201
#
#         confusion_matrix
# 0    [[8, 0], [93, 112]]
# 1    [[8, 0], [119, 86]]
# 2    [[8, 0], [154, 51]]
# 3    [[8, 0], [189, 16]]
# 4     [[8, 0], [203, 2]]
# 5   [[8, 0], [104, 101]]
# 6    [[8, 0], [120, 85]]
# 7    [[8, 0], [131, 74]]
# 8    [[8, 0], [154, 51]]
# 9    [[8, 0], [189, 16]]
# 10   [[8, 0], [91, 114]]
# 11   [[8, 0], [112, 93]]
# 12   [[8, 0], [138, 67]]
# 13   [[8, 0], [170, 35]]
# 14    [[8, 0], [199, 6]]
# 15   [[8, 0], [93, 112]]
# 16   [[8, 0], [118, 87]]
# 17   [[8, 0], [140, 65]]
# 18   [[8, 0], [168, 37]]
# 19   [[8, 0], [195, 10]]
# 20   [[8, 0], [97, 107]]
# 21   [[8, 0], [118, 86]]
# 22   [[8, 0], [136, 68]]
# 23   [[8, 0], [181, 23]]
# 24    [[8, 0], [201, 3]]
#    fold  threshold  accuracy  balanced_accuracy  precision_genuine  \
# 0     1        0.7  0.563380           0.773171                1.0
# 1     2        0.7  0.511737           0.746341                1.0
# 2     3        0.7  0.572770           0.778049                1.0
# 3     4        0.7  0.563380           0.773171                1.0
# 4     5        0.7  0.542453           0.762255                1.0
#
#    recall_genuine  f1_genuine  fake_as_genuine  genuine_as_fake  \
# 0        0.546341    0.706625                0               93
# 1        0.492683    0.660131                0              104
# 2        0.556098    0.714734                0               91
# 3        0.546341    0.706625                0               93
# 4        0.524510    0.688103                0               97
#
#        confusion_matrix
# 0   [[8, 0], [93, 112]]
# 1  [[8, 0], [104, 101]]
# 2   [[8, 0], [91, 114]]
# 3   [[8, 0], [93, 112]]
# 4   [[8, 0], [97, 107]]
# UMBRAL GLOBAL FINAL: 0.7
# PROMEDIO: 0.7
# MEDIANA: 0.7
# STD: 0.0

# %% [markdown]
# **Visualización del Umbral Global por K-Fold**

# %%
eplt.figure(figsize=(7,4))
plt.plot(df_thresholds_cv["threshold"], df_thresholds_cv["balanced_accuracy"], marker="o", label="Balanced Accuracy")
plt.plot(df_thresholds_cv["threshold"], df_thresholds_cv["f1_genuine"], marker="o", label="F1 Genuine")
plt.axvline(UMBRAL_GLOBAL_FINAL, linestyle="--", label="Umbral final")
plt.title("Desempeño por umbral")
plt.xlabel("Threshold")
plt.ylabel("Métrica")
plt.legend()
plt.grid(True)
plt.show()
